# %%
#%매직명령어
# 그래프 출력 과정을 볼 수 있도록 설정
# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
#50개 난수 생성
data = np.random.rand(50)

# %%
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
seri = pd.Series(data)

# %%
print(seri)
# Out:
# 0     0.855861
# 1     0.006455
# 2     0.644841
# 3     0.922097
# 4     0.680535
# 5     0.693568
# 6     0.176382
# 7     0.516420
# 8     0.660388
# 9     0.755532
# 10    0.967294
# 11    0.798376
# 12    0.392611
# 13    0.016860
# 14    0.435803
# 15    0.997703
# 16    0.084880
# 17    0.878305
# 18    0.995714
# 19    0.409698
# 20    0.142402
# 21    0.613227
# 22    0.851141
# 23    0.037282
# 24    0.424259
# 25    0.462945
# 26    0.907975
# 27    0.972411
# 28    0.171316
# 29    0.309513
# 30    0.248622
# 31    0.863527
# 32    0.175523
# 33    0.849452
# 34    0.190291
# 35    0.598481
# 36    0.006698
# 37    0.616843
# 38    0.119546
# 39    0.703596
# 40    0.819207
# 41    0.084620
# 42    0.102456
# 43    0.217401
# 44    0.943720
# 45    0.101287
# 46    0.779796
# 47    0.485833
# 48    0.882168
# 49    0.799678
# dtype: float64

# %%
print(data)
# Out:
# [ 0.85586062  0.00645521  0.64484091  0.92209657  0.68053527  0.69356766
#   0.17638173  0.51642006  0.66038787  0.75553162  0.96729351  0.79837627
#   0.3926113   0.01685979  0.43580303  0.99770277  0.08487977  0.87830474
#   0.99571378  0.40969845  0.14240226  0.61322739  0.85114096  0.03728235
#   0.42425926  0.46294513  0.90797504  0.97241114  0.17131551  0.3095129
#   0.24862151  0.86352729  0.17552288  0.84945221  0.19029118  0.59848055
#   0.00669753  0.61684272  0.11954558  0.70359642  0.81920665  0.08462026
#   0.10245621  0.21740111  0.94372046  0.10128744  0.77979552  0.48583301
#   0.8821682   0.79967848]

# %%
seri.plot()

# %%
plt.style.use("ggplot")
seri.plot()

# %%
data_set = np.random.rand(10,3)

# %%
print(data_set)
# Out:
# [[ 0.68605496  0.64707785  0.08776257]
#  [ 0.00377828  0.0018984   0.05400589]
#  [ 0.24927257  0.8103439   0.35809917]
#  [ 0.46852332  0.94300857  0.89346876]
#  [ 0.99936344  0.19207521  0.80839756]
#  [ 0.03443147  0.98519884  0.10406293]
#  [ 0.8220563   0.18441259  0.22275903]
#  [ 0.27580634  0.95042174  0.1636806 ]
#  [ 0.1211199   0.38911545  0.68254385]
#  [ 0.81561741  0.40365479  0.80008628]]

# %%
print(data_set.shape)
# Out:
# (10, 3)

# %%
df = pd.DataFrame(data_set, columns=["A","B","C"])

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df)
# Out:
#           A         B         C
# 0  0.686055  0.647078  0.087763
# 1  0.003778  0.001898  0.054006
# 2  0.249273  0.810344  0.358099
# 3  0.468523  0.943009  0.893469
# 4  0.999363  0.192075  0.808398
# 5  0.034431  0.985199  0.104063
# 6  0.822056  0.184413  0.222759
# 7  0.275806  0.950422  0.163681
# 8  0.121120  0.389115  0.682544
# 9  0.815617  0.403655  0.800086

# %%
df
# Out:
#           A         B         C
# 0  0.686055  0.647078  0.087763
# 1  0.003778  0.001898  0.054006
# 2  0.249273  0.810344  0.358099
# 3  0.468523  0.943009  0.893469
# 4  0.999363  0.192075  0.808398
# 5  0.034431  0.985199  0.104063
# 6  0.822056  0.184413  0.222759
# 7  0.275806  0.950422  0.163681
# 8  0.121120  0.389115  0.682544
# 9  0.815617  0.403655  0.800086

# %%
df.plot()

# %%
df.plot(kind="bar")

# %%
df.plot(kind="barh")

# %%
df.plot(kind="area")

# %%
df.plot(kind="area", stacked=False)

# %%
seri2 = pd.Series(np.random.rand(5), index=["a","b","c","d","e"], name="series")

# %%
seri2.plot(kind="pie", autopct="%.2f", fontsize=20, figsize=(7,5))

# %%
import numpy as np

# %%
data1=[1,2,3,4,5]
#리스트를 넘파이 배열로 변환
arr1 = np.array(data1)
print(arr1)
print(arr1.shape)
# Out:
# [1 2 3 4 5]
# (5,)

# %%
data2=[[1,2,3],[4,5,6]]
arr2 = np.array(data2)
print(arr2)
print(arr2.shape)
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)

# %%
arr3 = np.array([[7,8,9],[10,11,12]])
arr2 + arr3
# Out:
# array([[-6, -6, -6],
#        [-6, -6, -6]])

# %%
arr2 - arr3
# Out:
# array([[-6, -6, -6],
#        [-6, -6, -6]])

# %%
arr2 * arr3
# Out:
# array([[ 7, 16, 27],
#        [40, 55, 72]])

# %%
arr2 / arr3
# Out:
# array([[ 0.14285714,  0.25      ,  0.33333333],
#        [ 0.4       ,  0.45454545,  0.5       ]])

# %%
arr2 * 2
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])
